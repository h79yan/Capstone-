# %%
import psycopg2
from psycopg2 import sql
import pandas as pd

# %%
def get_select_query_results(host, dbname, user, password, query, port=5432):
    try:
        # Ensure the query is a SELECT statement
        if not query.strip().lower().startswith("select"):
            raise ValueError("Only SELECT queries are allowed.")

        # Connect to PostgreSQL database
        connection = psycopg2.connect(
            host=host,
            database=dbname,
            user=user,
            password=password,
            port=port
        )
        cursor = connection.cursor()

        # Execute SQL query
        cursor.execute(query)

        # Fetch results
        records = cursor.fetchall()
        column_names = [desc[0] for desc in cursor.description]

        # Convert results to a pandas DataFrame
        df = pd.DataFrame(records, columns=column_names)
        return df

    except (Exception, psycopg2.Error) as error:
        print("Error while connecting to PostgreSQL: ", error)
    finally:
        # Closing database connection.
        if connection:
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")

# %%
df = get_select_query_results(host="34.123.21.31", dbname="quefoodhall", user="developuser", password="]&l381[czY:F@sV*", query="SELECT * FROM menu_table;")
# Out:
# PostgreSQL connection is closed

# %%
df.nunique()
# Out:
# restaurant_id         3909
# menu_id                 85
# category              9261
# food_name           118255
# food_description     88552
# food_price            3833
# dtype: int64
