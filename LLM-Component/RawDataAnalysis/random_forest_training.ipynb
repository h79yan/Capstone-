# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
df_food = pd.read_csv('../data/food_wo_description.csv')

# %%
encoder_food = LabelEncoder()
df_food['food_name_encoded'] = encoder_food.fit_transform(df_food['food_name'])
encoder_restaurant = LabelEncoder()
df_food['restaurant_id_encoded'] = encoder_food.fit_transform(df_food['restaurant_id'])

# %%
X = df_food[['estimated_calories']]
y_food = df_food['food_name_encoded']
y_restaurant = df_food['restaurant_id_encoded']

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
joblib.dump(scaler, '../FoodSuggestion/scaler.pkl')
# Out:
# ['../FoodSuggestion/scaler.pkl']

# %%
scaler.var_
# Out:
# array([50071.11722471])

# %%
try_trans = scaler.transform([[720]])
print(try_trans)
# Out:
# [[1.84772801]]
# C:\Repositories\LLM-Component\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
scal

# %%
X_train, X_test, y_food_train, y_food_test, y_restaurant_train, y_restaurant_test = train_test_split(
    X_scaled, y_food, y_restaurant, test_size=0.2, random_state=42
)

# %%
food_model = RandomForestClassifier(n_estimators=100, random_state=42)
food_model.fit(X_train, y_food_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print([14936][0])
# Out:
# 14936

# %%
food_model.predict([[3.322484]])
# Out:
# array([14936])

# %%
encoder_food.inverse_transform([23304])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 encoder_food.inverse_transform([23304])
#
# File C:\Repositories\LLM-Component\venv\Lib\site-packages\sklearn\preprocessing\_label.py:162, in LabelEncoder.inverse_transform(self, y)
#     156 diff = _setdiff1d(
#     157     ar1=y,
#     158     ar2=xp.arange(self.classes_.shape[0], device=device(y)),
#     159     xp=xp,
#     160 )
#     161 if diff.shape[0]:
# --> 162     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     163 y = xp.asarray(y)
#     164 return xp.take(self.classes_, y, axis=0)
#
# ValueError: y contains previously unseen labels: [23304]

# %%
df_result = df_food[(df_food['food_name_encoded'] == 23304) & (df_food['restaurant_id_encoded'] == predicted_restaurant_label)]
# Out:
#        restaurant_id        category      food_name  food_price  \
# 20997            720  Picked for you  Mexican Pizza        13.5
# 21057            720      Appetizers  Mexican Pizza        13.5
#
#        estimated_calories                   food_type  food_name_encoded  \
# 20997                1550  Lunch/Dinner (Main Course)              23304
# 21057                1550  Lunch/Dinner (Main Course)              23304
#
#        restaurant_id_encoded
# 20997                    686
# 21057                    686

# %%
df_food
# Out:
#         restaurant_id        category                           food_name  \
# 0                   1       Smoothies                                   J
# 1                   1       Smoothies                                  Ti
# 2                   1       Smoothies                 AshuntiWay Smoothie
# 3                   1       Smoothies                  Jimmy Jam Smoothie
# 4                   1       Smoothies                                J Ti
# ...               ...             ...                                 ...
# 107410           3918  Picked for you                  Super Smash Burger
# 107411           3918         Burgers                  Super Smash Burger
# 107412           3918         Burgers            Super Smash Cheeseburger
# 107413           3918         Burgers      Super Smash Bacon Cheeseburger
# 107414           3918         Burgers  Super Smash BBQ Bacon Cheeseburger
#
#         food_price  estimated_calories  food_type  food_name_encoded  \
# ...

# %%
restaurant_model = RandomForestClassifier(n_estimators=100, random_state=42)
restaurant_model.fit(X_train, y_restaurant_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
joblib.dump(food_model, "food_model.pkl")
joblib.dump(restaurant_model, "restaurant_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(encoder_food, "food_encoder.pkl")
joblib.dump(encoder_restaurant, "restaurant_encoder.pkl")
# Out:
# ['restaurant_encoder.pkl']

# %%
X_train
# Out:
# array([[ 3.32248444],
#        [-0.47613061],
#        [ 0.86455705],
#        ...,
#        [-0.02923473],
#        [ 0.41766116],
#        [-0.69957856]])
